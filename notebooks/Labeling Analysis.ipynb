# %% [markdown]
# # Distribution of labels and labeling types

# %%
cat ../data/README.txt
# Out:
# ########################################
#
# The ExtraSensory Dataset
#
# Primary data files (features and labels)
#
# ########################################
#
# The ExtraSensory Dataset was collected by
# Yonatan Vaizman and Katherine Ellis, with the supervision of Gert Lanckriet.
# Department of Electrical and Computer Engineering,
# University of California, San Diego.
#
# The dataset is publicly available.
# Any usage of the dataset for publications requires citing the official paper that introduced the dataset:
# Recognizing Detailed Human Context In-the-Wild from Smartphones and Smartwatches
# by Yonatan Vaizman, Katherine Ellis, and Gert Lanckriet
# On April 2017, the paper was accepted to IEEE Pervasive Computing.
# (In the website, we refer to this original paper as Vaizman2017a. Please check http://extrasensory.ucsd.edu for updates on the formal reference to cite!)
#
# ########################################
#
# Content of the primary data files:
# ...

# %%
import pandas as pd
import numpy as np
import time
import importlib.machinery
es = importlib.machinery.SourceFileLoader('extrasense','/home/sac086/extrasensory/extrasense/extrasense.py').load_module()
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit, ShuffleSplit, KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from collections import Counter

# %%
all_df = es.get_impersonal_data(data_type="activity")

# %%
all_df.head(30)
# Out:
#                                  user_id  raw_acc:magnitude_stats:mean  \
# 0   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.019125
# 1   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.027085
# 2   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.019498
# 3   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.014249
# 4   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.015960
# 5   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.018011
# 6   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.014820
# 7   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.009072
# 8   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.008826
# 9   098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.007230
# 10  098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.009332
# 11  098A72A5-E3E5-4F54-A152-BBDA0DF7B694                      1.005119
# ...

# %%
counts = all_df['label_source'].value_counts()
counts
# Out:
#  2.0    263067
# -1.0     68750
#  1.0     23313
#  6.0     10921
#  4.0      6996
#  5.0      3239
#  0.0       606
#  3.0       164
# Name: label_source, dtype: int64

# %%
counts =
